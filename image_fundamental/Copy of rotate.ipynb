# %%
# !wget https://www.dropbox.com/s/xg78kiae02d4u8f/Conan.jpg --no-check-certificate
# Out:
# --2021-11-09 09:58:30--  https://www.dropbox.com/s/xg78kiae02d4u8f/Conan.jpg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6027:18::a27d:4812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/xg78kiae02d4u8f/Conan.jpg [following]
# --2021-11-09 09:58:31--  https://www.dropbox.com/s/raw/xg78kiae02d4u8f/Conan.jpg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca48187bb92160d909eb7ae0c43.dl.dropboxusercontent.com/cd/0/inline/BZpSWV8lLVDhOWQBUugQ2VQeh0ApHl_zmYPZXt0T_3VnEwkQH2ADxOs_0t4RE2A5fIu-ftKl8JTbkQx6oVrbt8-nokbPruV1utsMYt24GfN3jO2lptVHu-KW_eK3oE7PkiChaGlk7QDFwfKO7yc0qxGT/file# [following]
# --2021-11-09 09:58:31--  https://uca48187bb92160d909eb7ae0c43.dl.dropboxusercontent.com/cd/0/inline/BZpSWV8lLVDhOWQBUugQ2VQeh0ApHl_zmYPZXt0T_3VnEwkQH2ADxOs_0t4RE2A5fIu-ftKl8JTbkQx6oVrbt8-nokbPruV1utsMYt24GfN3jO2lptVHu-KW_eK3oE7PkiChaGlk7QDFwfKO7yc0qxGT/file
# Resolving uca48187bb92160d909eb7ae0c43.dl.dropboxusercontent.com (uca48187bb92160d909eb7ae0c43.dl.dropboxusercontent.com)... 162.125.65.15, 2620:100:6027:15::a27d:480f
# Connecting to uca48187bb92160d909eb7ae0c43.dl.dropboxusercontent.com (uca48187bb92160d909eb7ae0c43.dl.dropboxusercontent.com)|162.125.65.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49612 (48K) [image/jpeg]
# Saving to: ‘Conan.jpg’
#
# Conan.jpg           100%[===================>]  48.45K  --.-KB/s    in 0.005s
#
# 2021-11-09 09:58:31 (8.90 MB/s) - ‘Conan.jpg’ saved [49612/49612]

# %%
# import the necessary packages
import matplotlib.pyplot as plt
import argparse
import imutils
import cv2

# %%
def plt_imshow(title, image):
    # convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
args = {
    "image": "Conan.jpg"
}

# %%
# load the image and show it
image = cv2.imread(args["image"])
plt_imshow("Original", image)

# grab the dimensions of the image and calculate the center of the
# image
(h, w) = image.shape[:2]
(cX, cY) = (w // 2, h // 2)

# rotate our image by 45 degrees around the center of the image
M = cv2.getRotationMatrix2D((cX, cY), 45, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
plt_imshow("Rotated by 60 Degrees", rotated)

# rotate our image by -90 degrees around the image
M = cv2.getRotationMatrix2D((cX, cY), -90, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
plt_imshow("Rotated by -90 Degrees", rotated)

# %%
# rotate our image around an arbitrary point rather than the center
M = cv2.getRotationMatrix2D((5, 5), 45, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))
plt_imshow("Rotated by Arbitrary Point", rotated)

# %%
# use our imutils function to rotate an image 180 degrees
rotated = imutils.rotate(image, 180)
plt_imshow("Rotated by 180 Degrees", rotated)

# %%
# rotate our image by 33 degrees counterclockwise, ensuring the
# entire rotated image still views in the viewing area
rotated = imutils.rotate_bound(image, -33)
plt_imshow("Rotated Without Cropping", rotated)
